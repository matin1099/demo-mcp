# %%
import httpx
import bf4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import httpx
# ----> 2 import bf4
#
# ModuleNotFoundError: No module named 'bf4'
